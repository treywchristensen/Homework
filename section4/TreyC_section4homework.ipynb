# %%
# Flow Control Methods: Questions 1-4
# 1. Create an if statement: if 'age' is greater than or equal to 25...

age = 33

if age >= 25:
    print("Renting a car is more affordable.")
if age < 25:
    print("Renting a car is very expensive")

# 2. Create and chain an if-else statement

age = 16
if age >= 25:
    script = "Renting a car is more affordable."
else: #less than 25 but greater or equal to 18
    if age >= 18:
        script = "Renting a car is very expensive"
    else:  #age is less than 18
        if age < 18:
            script = "You cannot legally rent a car."
print(script)

# 3. Loop over the following string to (1) count all the characters in the string and (2) print out all the vowels -- "The quick brown fox jumps over the lazy dog"

#Count characters in string
phrase = "The quick brown fox jumps over the lazy dog"
vowels = ['a', 'e', 'i', 'o', 'u']
char = 0

for num in phrase:
    char += 1
print(char)

#print out vowels
for letters in phrase:
    if letters in vowels:
        print(letters)

# 4. Write a nested loop that prints out every piece of clothing from the `couture` list, in every fashionable color from the `panettone` set: couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] and panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"]
panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for piece in couture:
    for color in panettone:
        print(color, piece)
# Out:
# Renting a car is more affordable.
# You cannot legally rent a car.
# 43
# e
# u
# i
# o
# o
# u
# o
# e
# e
# a
# o
# burnt sienna trousers
# auburn trousers
# Dark Sapphire trousers
# gunmetal blue trousers
# maple trousers
# cerise trousers
# aqua trousers
# fuchsia trousers
# burnt sienna blouse
# auburn blouse
# Dark Sapphire blouse
# gunmetal blue blouse
# maple blouse
# cerise blouse
# aqua blouse
# fuchsia blouse
# burnt sienna bandana
# auburn bandana
# Dark Sapphire bandana
# gunmetal blue bandana
# maple bandana
# cerise bandana
# aqua bandana
# fuchsia bandana
# burnt sienna cumber band
# auburn cumber band
# Dark Sapphire cumber band
# gunmetal blue cumber band
# maple cumber band
# cerise cumber band
# aqua cumber band
# fuchsia cumber band
# burnt sienna blazer
# auburn blazer
# Dark Sapphire blazer
# gunmetal blue blazer
# maple blazer
# cerise blazer
# aqua blazer
# fuchsia blazer
# burnt sienna vest
# auburn vest
# Dark Sapphire vest
# gunmetal blue vest
# maple vest
# cerise vest
# aqua vest
# fuchsia vest
# burnt sienna french beret
# auburn french beret
# Dark Sapphire french beret
# gunmetal blue french beret
# maple french beret
# cerise french beret
# aqua french beret
# fuchsia french beret
# burnt sienna scarf
# auburn scarf
# Dark Sapphire scarf
# gunmetal blue scarf
# maple scarf
# cerise scarf
# aqua scarf
# fuchsia scarf
# burnt sienna stole
# auburn stole
# Dark Sapphire stole
# gunmetal blue stole
# maple stole
# cerise stole
# aqua stole
# fuchsia stole

# %%
# Flow Control Methods: Questions 5-8
# 5. Use range as a loop to calculate the sum of all the numbers from 1 to 100

sum = 0
for total in range(1,101):
    sum+=total
print(sum)

# 6. Print the second item in this fruits list. ["apple", "banana", "cherry"]

list = ["apple", "banana", "cherry"]
print(list[1])

# 7. Change the value from "apple" to "kiwi", in the fruits list. ["apple", "banana", "cherry"]

fruits = ["apple", "banana", "cherry"]
fruits[0] = "kiwi"
fruits

# 8. Use the append method to add "orange" to the fruits list. ["apple", "banana", "cherry"]

list = ["apple", "banana", "cherry"]
list.append("orange")
list
# Out:
# 5050
# banana
# ['apple', 'banana', 'cherry', 'orange']

# %%
# Flow Control Methods: Questions 9-14
# 9. Use the insert method to add "lemon" as the second item in the fruits list. ["apple", "banana", "cherry"]

fruits = ["apple", "banana", "cherry"]
fruits.insert(1, 'lemon')
print(fruits)

# 10. Use the remove method to remove "banana" from the fruits list. ["apple", "banana", "cherry"]

list = ["apple", "banana", "cherry"]
list.remove("banana")
print(list)

# 11. Use negative indexing to print the 3rd and 2nd to last items in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

list1 = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(list1[-2])
print(list1[-3])

# 12. Use a range of indexes to print the third, fourth, and fifth item in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
# Made into string for easy range print

list2 = "apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"
print(list2[2:5])

# 13. Use the correct syntax to print the number of items in the list. ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

list3 = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

print(len(list3))

# 14. Use the correct syntax to sort this list in reverse order ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

list4 = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

list4.sort(reverse=True)
print(list4)
# Out:
# ['apple', 'lemon', 'banana', 'cherry']
# ['apple', 'cherry']
# melon
# kiwi
# ('cherry', 'orange', 'kiwi')
# 7
# ['orange', 'melon', 'mango', 'kiwi', 'cherry', 'banana', 'apple']

# %% [markdown]
# 1. What does one need to do to use a module?
# > **Download and Import**
# 2. Name a Module (not the DateTime Nodule) we looked at and write a line of 2 of code as an example using this module.
# > **Math Module**
#     > - **print(math.sqrt(144))**
#     > - **print(math.pi)**
# 3. What is a benefit of using Exception handling??
# > **When errors are raised, your program won't crash. It will get past errors if they are present.**
# 4. What are the 4 components used for Python Exception Handling?
# > a. **try**
# > b. **except**
# > c. **else**
# > d. **finally**
# 5. NumPy arrays are like what Python data type?
# > **List**
# 6. What is one of the main benefits of using NumPy arrays.
# > **Less Memory & Faster**
# 7. What is one of the main requirements about the 'dtype' of NumPy arrays?
# > **Changes array's data type**
# 8. Of the 10 uses of NumPy, name 2.
# > - **Statistical Operations**
# > - **Stacking**
# 9. Name one of the other libraries we'll use with NumPy?
# > **Pandas**
# 10. What is the shape of NumPy arrays?
# > **Multiple different shapes defined by the dimensions**
# 11. What is a Tensor?
# > **An array with 3+ dimensions**
# 12. Name a reason why it's better using NumPy for Data Analysis than using a Python List?
# > a. **Less Memory**
# > b. **Faster**
# > c. **More Convenient**
# 13. When creating an "empty" array, where do the elements come from?
# > **The elements in an empty array are filled based on the state of the memory.**

# %%
# DateTime Module

# Current Date/Time
import datetime
now = datetime.datetime.now()
print(now)

# Month
from datetime import date
today = date.today()
print(today.strftime("%B"))

# Simple Function
firstname = "Clayton"
day = "Sunday"
print(f"Hi {firstname}! Happy {day}!")
print(f"Hi {firstname}! Happy day!")

#Exception Handling
try:
    print(t)
except:
    print("That won't work") 

try:
    print("This should work")
except:
    print("What is going on?")
else:
    print("I don't know what happened")

try:
    print(t)
except:
    print("Let's move on")
finally:
    print("It's finally over")
# Out:
# 2023-05-15 19:24:58.771485
# May
# Hi Clayton! Happy Sunday!
# Hi Clayton! Happy day!
# That won't work
# This should work
# I don't know what happened
# Let's move on
# It's finally over
